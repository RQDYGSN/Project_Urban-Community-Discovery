# %%
import dgl
import dgl.function as fn
import torch.nn.functional as F
from dgl import DGLGraph
import time
from dgl.data import citation_graph as citegrh
from scipy import sparse
from sklearn import preprocessing 
from tqdm import tqdm
import networkx as nx
import geopandas as gpd
import pandas as pd 
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
import math
import random
import community
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from modularity_maximization import partition
device = torch.device('cpu')
# Out:
# Using backend: pytorch

# %%
sample_num = 2000

# %% [markdown]
# ### Graph Construction —— Population Flow

# %%
# 确认节点数量
bs_gpd = gpd.read_file('../../data/basestation-gis/basestation_aggregation.shp')
bs_gpd = bs_gpd.iloc[:sample_num:, ::]
bs_num = bs_gpd.shape[0]

# 构造图节点
nodes_list = list(range(bs_num))
G = nx.Graph()
G.add_nodes_from(nodes_list)

# 读取邻接矩阵adjacent
# 以工作日(周一)的早高峰时段为例
adj = pd.read_csv('../../data/adj/adj_20151109_0002.csv')
adj = adj.iloc[:, 1:].values
adj = adj[:sample_num:, :sample_num:]
adj = adj + adj.T
for i in range(sample_num): adj[i, i] = 0
    
# for i in range(bs_num):
#     if (adj[i]==0).all():
#         adj[i, :] = 0.0001
#         adj[:, i] = 0.0001

# D_12 = np.diag(np.power(np.sum(adj, axis=0)+0.00001, -1/2))
# adj_norm = np.dot(np.dot(D_12, adj), D_12)

for i in tqdm(range(bs_num)):
    for j in range(bs_num):
        tmp = adj[i, j]
        if tmp>0: G.add_edge(i, j, weight=tmp)
# Out:
# 100%|██████████| 2000/2000 [00:03<00:00, 564.58it/s]

# %% [markdown]
# ### Graph Construction —— Geographic Reachability

# %% [markdown]
# ### Feature Construction —— Equality Contribution

# %%
feature = pd.read_csv('../../data/features/features_wf_new.csv')
feature = feature.iloc[:, 1::].values

# %%
feature = feature[:sample_num:, :]

# %% [markdown]
# ### Prior Information

# %%
partition = community.best_partition(G)
partition_count = {}
for key, value in partition.items():
    if value not in partition_count:
        partition_count[value] = 1
    else:
        partition_count[value] = partition_count[value] + 1

# %%
print(community.modularity(partition, G, weight='weight'))
clusters_number = 0
for key, value in partition_count.items():
    if value > 1:
        clusters_number = clusters_number + 1
print(clusters_number)
remapping = {}
idx = 0
for key, value in partition_count.items():
    if value>1 and key not in remapping:
        remapping[key] = idx
        idx = idx + 1

alpha = 0.01
W_prior = np.zeros((bs_num, clusters_number))
for key, value in partition.items():
    try:
        W_prior[key, remapping[value]] = alpha
    except:
        pass
# Out:
# 0.6013691867427065
# 10

# %% [markdown]
# ### Net Initial

# %% [markdown]
# np.identity()只能创建方阵，np.eye()可以创建一般矩阵，主对角线为1，其余元素为0。

# %%
gcn_msg = fn.copy_src(src='h', out='m')
gcn_reduce = fn.sum(msg='m', out='h')

A = torch.from_numpy(adj).float()
d = torch.from_numpy(np.sum(adj, axis=1).reshape((-1, 1))).float()
mm = np.sum(adj)
B = A - torch.mm(d, d.T)/mm
B_norm = B/mm
DG1 = dgl.DGLGraph()
DG1.from_networkx(G)
features = torch.from_numpy(feature).float()

# D_ = th.diag(th.pow(d.view(-1), -1/2))
# A_norm = th.mm(th.mm(D_, A), D_)

# k = 15
in_dim = features.size()[1]
out_dim = clusters_number

# %%
class GCNLayer(nn.Module):
    def __init__(self, in_feats, out_feats):
        super(GCNLayer, self).__init__()
        self.linear = nn.Linear(in_feats, out_feats)

    def forward(self, g, feature):
        # Creating a local scope so that all the stored ndata and edata
        # (such as the `'h'` ndata below) are automatically popped out
        # when the scope exits.
        with g.local_scope():
            g.ndata['h'] = feature
            g.update_all(gcn_msg, gcn_reduce)
            h = g.ndata['h']
            return self.linear(h)

# %%
class GCN_model(nn.Module):
    def __init__(self, in_feats, out_feats):
        super(GCN_model, self).__init__()
        self.layer = GCNLayer(in_feats, out_feats)
        # self.B = B

    def forward(self, g, features, beta):
        global gcn_output
        n = nn.Softmax(dim=1)
        
        gcn_output = self.layer(g, features)
        weight_feature = n(gcn_output)
        W_noise = torch.div(torch.exp(weight_feature)-1, torch.exp(weight_feature)+1)*beta
        return W_noise

# %%
class GCN_decoder(nn.Module):
    def __init__(self, in_feats, out_feats):
        super(GCN_decoder, self).__init__()
        self.layer = GCNLayer(in_feats, out_feats)

    def forward(self, g, features):
        gcn_output = self.layer(g, features)
        return gcn_output

# %%
# clusters_number = 15
A_hat = torch.tensor(nx.adjacency_matrix(G).todense(), dtype=np.float) # a matrix: A
X = np.identity(G.number_of_nodes(), dtype=np.float)

class OURS(nn.Module):
    def __init__(self, B_norm, num_feat, num_hidden):
        super(OURS, self).__init__()
        self.num_feat = num_feat # 特征数 f
        self.num_hidden = num_hidden # 隐含数 h
        self.B_norm = B_norm.float()
        self.W_0 = nn.Parameter(torch.ones(num_feat, num_hidden)+W_prior) # [1][f*h]

    def forward(self, X, A_hat,temp, epoch, W_noise): # X貌似暂时没有用到
        global featureSelector # 
        global weight_feature # 
        f = nn.Softmax(dim=1)
        featureSelector = f(self.W_0 + W_noise) # [1][f*h]
        results = torch.zeros(self.W_0.size()) # [0][f*h]
        x = 2*(epoch+1) # x次取平均,目测这个目的是为了稳定。
        for i in range(x):
            # logits --> self.W_0: [batch_size, num_features] 非规范化对数概率
            # tau: 非负的对抗强度。
            # hard: 如果 True, 返回的样本将会离散为 one-hot 向量
            results += F.gumbel_softmax(self.W_0,tau=temp,hard=False)
        weight_feature = results/x # [-][f*h]

        # H = torch.mm(torch.mm(weight_feature.T, B), weight_feature) # weight_feature 就是我们要求的U
        H = torch.mm(torch.mm(weight_feature.T, self.B_norm), weight_feature) # weight_feature 就是我们要求的U
        Hh = torch.div(H, H.sum(axis=0)) # 按照每一列进行归一化，列为axis=0的方向。
        m = nn.Softmax(dim=0)
        return m(Hh)
    
def lossFn(output): 
    return torch.trace(-torch.log(output))

# %% [markdown]
# ### Partition Process

# %% [markdown]
# <font color='red'>Experiment Set: $\alpha = 0.01$</font>

# %%
gamma1 = 1
gamma2 = 10

# %%
num_feat = len(G.nodes()) # f = 节点数
num_hidden = clusters_number # h = 聚类数

model_base = OURS(A_hat, num_feat, num_hidden).to(device)
model_gcn = GCN_model(in_dim, out_dim)
model_decoder = GCN_decoder(out_dim, in_dim)

optimizer_base = optim.Adam(model_base.parameters(),lr=1.5e-2)
optimizer_gcn = torch.optim.Adam(model_gcn.parameters(), lr=1e-2)
optimizer_decoder = torch.optim.Adam(model_decoder.parameters(), lr=1e-2)
# optimizer = optim.Adam(model.parameters(),lr=1e-2,weight_decay=0,betas=(0.5, 0.999), eps=1e-08)

A_hat_tensor = torch.Tensor(A_hat.float()).to(device)
X_tensor = torch.Tensor(X).to(device)

loss_hist = []
modularity_hist = []
# acc_hist = []
temp = 3
beta = 1

for epoch in range(500):
    model_base.train()
    model_base.zero_grad()
    model_gcn.train()
    model_gcn.zero_grad()
    model_decoder.train()
    model_decoder.zero_grad()
    if(epoch == 75):
        temp = 2.75
    elif(epoch == 100):
        temp = 2.5
    elif(epoch == 125):
        temp = 2
    elif(epoch == 150):
        temp = 1.8
    elif(epoch == 175):
        temp = 1.25
    elif(epoch == 250):
        temp = 1.00
    elif(epoch == 300):
        temp = 0.75
    elif(epoch == 320):
        temp = 0.50
    elif(epoch == 400):
        temp = 0.20
    W_noise = model_gcn(DG1, features, beta)
    output = model_base(X_tensor, A_hat_tensor, temp, epoch, W_noise)
    features_rec = model_decoder(DG1, weight_feature)
    ############################################
    loss = gamma1*lossFn(output) + gamma2*torch.norm(features_rec - features, p='fro')/features.numel()
    loss_hist.append(loss.item())
    ############################################
    gumbel_matrix = weight_feature.detach().max(dim=1)[1] # 每个节点的标签组成的tensor
    labels_pred = gumbel_matrix.data.numpy()
    modularity = community.modularity(dict(zip(list(range(len(labels_pred))), labels_pred)), G, weight='weight')
    modularity_hist.append(modularity)
    
    if epoch%10==0: 
        print('Epoch: ', epoch, '; Loss: ', round(loss.item(), 4), '; Modulariy: ', round(modularity, 4))
    loss.backward()
    optimizer_base.step()
    optimizer_gcn.step()
# Out:
# Epoch:  0 ; Loss:  23.2794 ; Modulariy:  -0.0035
# Epoch:  10 ; Loss:  23.2732 ; Modulariy:  0.0039
# Epoch:  20 ; Loss:  23.2676 ; Modulariy:  -0.0043
# Epoch:  30 ; Loss:  23.2615 ; Modulariy:  0.0086
# Epoch:  40 ; Loss:  23.2556 ; Modulariy:  0.0266
# Epoch:  50 ; Loss:  23.2479 ; Modulariy:  0.0471
# Epoch:  60 ; Loss:  23.2382 ; Modulariy:  0.0856
# Epoch:  70 ; Loss:  23.2242 ; Modulariy:  0.1253
# Epoch:  80 ; Loss:  23.1952 ; Modulariy:  0.1449
# Epoch:  90 ; Loss:  23.1644 ; Modulariy:  0.2079
# Epoch:  100 ; Loss:  23.104 ; Modulariy:  0.2497
# Epoch:  110 ; Loss:  23.0463 ; Modulariy:  0.2811
# Epoch:  120 ; Loss:  22.9771 ; Modulariy:  0.3191
# Epoch:  130 ; Loss:  22.7662 ; Modulariy:  0.3228
# Epoch:  140 ; Loss:  22.6398 ; Modulariy:  0.3441
# Epoch:  150 ; Loss:  22.3955 ; Modulariy:  0.3603
# Epoch:  160 ; Loss:  22.2251 ; Modulariy:  0.3589
# Epoch:  170 ; Loss:  22.0332 ; Modulariy:  0.3711
# Epoch:  180 ; Loss:  21.3957 ; Modulariy:  0.3981
# Epoch:  190 ; Loss:  21.1009 ; Modulariy:  0.4334
# Epoch:  200 ; Loss:  20.7664 ; Modulariy:  0.4489
# Epoch:  210 ; Loss:  20.3805 ; Modulariy:  0.4644
# Epoch:  220 ; Loss:  19.9809 ; Modulariy:  0.4683
# Epoch:  230 ; Loss:  19.6077 ; Modulariy:  0.4783
# Epoch:  240 ; Loss:  19.2854 ; Modulariy:  0.4822
# Epoch:  250 ; Loss:  18.7749 ; Modulariy:  0.4904
# Epoch:  260 ; Loss:  18.6129 ; Modulariy:  0.4956
# Epoch:  270 ; Loss:  18.4996 ; Modulariy:  0.4958
# Epoch:  280 ; Loss:  18.423 ; Modulariy:  0.4964
# Epoch:  290 ; Loss:  18.3603 ; Modulariy:  0.4985
# Epoch:  300 ; Loss:  18.2258 ; Modulariy:  0.4984
# Epoch:  310 ; Loss:  18.204 ; Modulariy:  0.4999
# Epoch:  320 ; Loss:  18.1513 ; Modulariy:  0.5
# Epoch:  330 ; Loss:  18.1436 ; Modulariy:  0.5002
# Epoch:  340 ; Loss:  18.1344 ; Modulariy:  0.5015
# Epoch:  350 ; Loss:  18.129 ; Modulariy:  0.5018
# Epoch:  360 ; Loss:  18.1246 ; Modulariy:  0.5019
# Epoch:  370 ; Loss:  18.1226 ; Modulariy:  0.5012
# Epoch:  380 ; Loss:  18.1182 ; Modulariy:  0.5012
# Epoch:  390 ; Loss:  18.1139 ; Modulariy:  0.5012
# Epoch:  400 ; Loss:  18.0994 ; Modulariy:  0.5014
# Epoch:  410 ; Loss:  18.097 ; Modulariy:  0.5015
# Epoch:  420 ; Loss:  18.0934 ; Modulariy:  0.5028
# Epoch:  430 ; Loss:  18.0906 ; Modulariy:  0.5028
# Epoch:  440 ; Loss:  18.0875 ; Modulariy:  0.5035
# Epoch:  450 ; Loss:  18.0856 ; Modulariy:  0.5035
# Epoch:  460 ; Loss:  18.0822 ; Modulariy:  0.5036
# Epoch:  470 ; Loss:  18.0822 ; Modulariy:  0.5037
# Epoch:  480 ; Loss:  18.0804 ; Modulariy:  0.5039
# Epoch:  490 ; Loss:  18.0773 ; Modulariy:  0.5039

# %%
print(torch.min(W_noise), torch.max(W_noise))
# Out:
# tensor(0.0412, grad_fn=<MinBackward1>) tensor(0.0575, grad_fn=<MaxBackward1>)

# %% [markdown]
# **GCN noise $\beta = 1.0$, $\gamma_1 = 1$, $\gamma_2 = 10$**

# %%
plt.figure(figsize=(20, 6))
plt.subplot(1, 2, 1)
plt.plot(loss_hist, color='red')
plt.grid(True)
plt.subplot(1, 2, 2)
plt.plot(modularity_hist, color='blue')
plt.grid(True)
plt.show()

print(weight_feature.detach().size())
gumbel_matrix = weight_feature.detach().max(dim=1)[1] # 每个节点的标签组成的tensor
labels_pred = gumbel_matrix.data.numpy()
pos = nx.spring_layout(G)
plt.figure(figsize=(10, 10))
plt.axis('off')
nx.draw_networkx(G, pos=pos, node_size=100, node_color="r", with_labels=False)
options = {
    'node_color': 'red',
    'node_size': 10,
    'line_color': 'grey',
    'linewidths': 0,
    'width': 0.1,
}
plt.show()

print(max(modularity_hist))
# Out:
# torch.Size([2000, 10])
# 0.5039421921404178

# %% [markdown]
# **GCN noise $\beta = 1.0$, $\gamma_1 = 1$, $\gamma_2 = 1$**

# %%
plt.figure(figsize=(20, 6))
plt.subplot(1, 2, 1)
plt.plot(loss_hist, color='red')
plt.grid(True)
plt.subplot(1, 2, 2)
plt.plot(modularity_hist, color='blue')
plt.grid(True)
plt.show()

print(weight_feature.detach().size())
gumbel_matrix = weight_feature.detach().max(dim=1)[1] # 每个节点的标签组成的tensor
labels_pred = gumbel_matrix.data.numpy()
pos = nx.spring_layout(G)
plt.figure(figsize=(10, 10))
plt.axis('off')
nx.draw_networkx(G, pos=pos, node_size=100, node_color="r", with_labels=False)
options = {
    'node_color': 'red',
    'node_size': 10,
    'line_color': 'grey',
    'linewidths': 0,
    'width': 0.1,
}
plt.show()

print(max(modularity_hist))
# Out:
# torch.Size([2000, 10])
# 0.521712399614001

# %% [markdown]
# **GCN noise $\beta = 1.0$, $\gamma_1 = 0$, $\gamma_2 = 1$**

# %%
plt.figure(figsize=(20, 6))
plt.subplot(1, 2, 1)
plt.plot(loss_hist, color='red')
plt.grid(True)
plt.subplot(1, 2, 2)
plt.plot(modularity_hist, color='blue')
plt.grid(True)
plt.show()

print(weight_feature.detach().size())
gumbel_matrix = weight_feature.detach().max(dim=1)[1] # 每个节点的标签组成的tensor
labels_pred = gumbel_matrix.data.numpy()
pos = nx.spring_layout(G)
plt.figure(figsize=(10, 10))
plt.axis('off')
nx.draw_networkx(G, pos=pos, node_size=100, node_color="r", with_labels=False)
options = {
    'node_color': 'red',
    'node_size': 10,
    'line_color': 'grey',
    'linewidths': 0,
    'width': 0.1,
}
plt.show()

print(max(modularity_hist))
# Out:
# torch.Size([2000, 10])
# 0.02517932974371271

# %% [markdown]
# **GCN noise $\beta = 1.0$, $\gamma_1 = 1$, $\gamma_2 = 0$**

# %%
plt.figure(figsize=(20, 6))
plt.subplot(1, 2, 1)
plt.plot(loss_hist, color='red')
plt.grid(True)
plt.subplot(1, 2, 2)
plt.plot(modularity_hist, color='blue')
plt.grid(True)
plt.show()

print(weight_feature.detach().size())
gumbel_matrix = weight_feature.detach().max(dim=1)[1] # 每个节点的标签组成的tensor
labels_pred = gumbel_matrix.data.numpy()
pos = nx.spring_layout(G)
plt.figure(figsize=(10, 10))
plt.axis('off')
nx.draw_networkx(G, pos=pos, node_size=100, node_color="r", with_labels=False)
options = {
    'node_color': 'red',
    'node_size': 10,
    'line_color': 'grey',
    'linewidths': 0,
    'width': 0.1,
}
plt.show()

print(max(modularity_hist))
# Out:
# torch.Size([2000, 10])
# 0.5133910816170028
